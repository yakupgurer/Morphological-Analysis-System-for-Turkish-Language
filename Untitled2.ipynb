# %%
from flask import Flask, render_template, request
import re
# %run FiilEkAyrimi.ipynb
#from FiilEkAyrimi import deger
from difflib import get_close_matches
import numpy as np
#%run Untitled1.ipynb
import random


app = Flask(__name__)

## global tanımlamalar (ekler)

ek_dosyalar = {
        "Opt":["yalım","yelim","alım","elim"],
        "Opt+A2sg":["yasın","yesin","asın","esin"],
        "Opt+A2pl":["yasınız","yesiniz","asınız","esiniz"],
        "Opt+A1sg":["yayım","yeyim","ayım","eyim"],
        ## noun suffixes
        "Pl": ["lar", "ler"],
        ## case suffixes
        "Dat": ["ya","ye","e","a","na","ne"],
        "Loc": ["da","de","ta","te","nde","nda"],
        "Abl": ["dan","den","tan","ten","ndan","nden"],
        "Gen": ["nın","nin","nun","nün","ın","in","un","ün","yın","yin","yun","yün","ım","im","um","üm","m"],
        "Acc": ["yı","yi","yu","yü","ı","i","u","ü","nı","ni","nu","nü"],
        "Inst": ["yla","yle","la","le"],
        "P1sg": ["ım","im","um","üm","m","yum"],
        "P2sg": ["ın","in","un","ün","n","yun"],
        "P3sg": ["sı","si","su","sü","ı","i","u","ü","yu"],
        "P1pl": ["ımız","imiz","umuz","ümüz","mız","miz","muz","müz","yumuz"],
        "P2pl": ["ınız","iniz","unuz","ünüz","nız","niz","nuz","nüz","yunuz"],
        "P3pl": ["ı", "i","u","ü","ları","leri"],
        "Dim": ["cık","cik","cuk","cük","çık","çik","çuk","çük","cığ","ciğ","cuğ","cüğ","çığ","çiğ","çuğ","çüğ"],
        "Dim2": ["cağız", "ceğiz"],
        "With":["lı","li","lu","lü"],
        "Without": ["sız", "siz","suz","süz"],
        "Since":["dır","dir","dur","dür","tır","tir","tur","tür"],
        "Related": ["sal", "sel"],
        "Ness":["lık","lik","luk","lük","lığ","liğ","luğ","lüğ"],
        "Acquire": ["lan", "len"],
        "Apply":["la","le"],
        "Resemb": ["ımsı","imsi","umsu","ümsü","msı","msi","msu","msü"],
        "Rel":["kı","ki","ku","kü"],
        "By": ["ca","ce"],
        "Cmp":["ca","ce"],
        "Agt":["cı","ci","cu","cü","yıcı","yici","yucu","yücü"],
        ## Adjective Suffixes
        "Become":["laş","leş"],
        "Ly":["ca","ce"],
        "Quite":["ca","ce"],
        ## number-person agreement suffixes
        "A1sg": ["yım","yim","yum","yüm","m","ım","im","um","üm"],
        "A2sg":["sın","sin","sun","sün","n","ın","in","un","ün"],
        "A3sg":[""],
        "A1pl": ["yız","yiz","k","yuz","yüz","ız","iz","uz","üz"],
        "A2pl":["sınız","siniz","sunuz","sünüz","nız","niz","nuz","nüz","ınız","iniz","unuz","ünüz"],
        "A3pl": ["lar","ler"],
        ### Numeral suffixes
        "Grouping": ["şar","şer","ız","iz","ar","er"],
        "Ordinal":["ıncı","inci","uncu","üncü","ncı","nci","ncu","ncü"],
        "Division":["da","de","ta","te"],

        ### Derivational Suffixes
        
        "Trap_Eki":["a","b","c","ç","d","e","f","g","ğ","h","ı","i","j","k","l","m","n","o","ö","p","r","s","ş","t","u","ü","v","y","z"],
        
    }


## global tanimlamalar sonu

def get_random_sentence(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        sentences = [line.strip() for line in file]
    return random.choice(sentences)

def find_longest_root(input_word, root_list):
    longest_root = ''
    for root in root_list:
        if input_word.startswith(root) and len(root) > len(longest_root):
            longest_root = root
   
    return longest_root

def correct_input(input_word, root_list, suffix_list):
    longest_root = find_longest_root(input_word, root_list)
    print(longest_root,"bu longest_root")
    geriyeKalanEk = input_word[len(longest_root):]
    print(geriyeKalanEk,"geriye kalan ek")
        
    if(geriyeKalanEk):
        suffix_correction = get_close_matches(geriyeKalanEk, suffix_list, n=1, cutoff=0.4)
        corrected_suffix = suffix_correction[0] if suffix_correction else geriyeKalanEk
        corrected_word = longest_root + corrected_suffix
        
    else:
        corrected_word = input_word

    return corrected_word


def sentence_splitter(text):
    sentence_endings = r"[.!?]"
    sentences = re.split(sentence_endings, text)
    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    return sentences

def tokenizer(text):
    tokens = text.split()
    return tokens

def parcala_ve_kontrol_et(input_str):
    
    ozel_durumlar = {
        #"ımız": ["ım", "ız"],
        #"sinler":["s","i","n","ler"],
        #"leri":["ler","i"],
        #"sının":["sı","nın"],
        #"elim":["e","lim"],

    }
    

    sonuclar = []
    en_uzun_ekler = []

    while input_str:
        bulundu = False
        ozelBulundu = False
        en_uzun_ek = ""
        ek_adi_list = []

        # Özel durum kontrolü
        for ozel_ek, ayrilma_sekli in ozel_durumlar.items():
            if input_str.startswith(ozel_ek):
                for ayrilma in ayrilma_sekli:
                    for ad, ekler in ek_dosyalar.items():
                        if ayrilma in ekler and input_str.startswith(ayrilma):
                            en_uzun_ek = ayrilma
                            ek_adi = f"({ad})"
                            ozelBulundu = True
                            if ozelBulundu:
                                input_str = input_str[len(en_uzun_ek):].strip()
                                ek_adi_list.append(ek_adi)

        if not ozelBulundu:
            for ad, ekler in ek_dosyalar.items():
                for ek in ekler:
                    if input_str.startswith(ek) and len(ek) >= len(en_uzun_ek):
                        en_uzun_ek = ek
                        ek_adi = f"({ad})"
                        bulundu = True

            if bulundu:
                input_str = input_str[len(en_uzun_ek):].strip()
                for ad, ekler in ek_dosyalar.items():
                    if en_uzun_ek in ekler:
                        ek_adi_list.append(f"({ad})")
            else:
                ek_adi_list.append(f"({input_str})")

        if ek_adi_list:
            sonuclar.append((f"-{en_uzun_ek} ", ek_adi_list))
            en_uzun_ek = ""
            ek_adi_list = []

    print(sonuclar,"YKAUP BABA SONUCLAR")
    return sonuclar


def endswithKontrolu(input_str):
    
    ozel_durumlar = {
        #"ımız": ["ım", "ız"],
        #"sinler":["s","i","n","ler"],
        #"leri":["ler","i"],
        #"sının":["sı","nın"],
        #"elim":["e","lim"],

    }

    sonuclar = []
    en_uzun_ekler = []
    
    while input_str:
        bulundu = False
        ozelBulundu = False
        en_uzun_ek = ""
        ek_adi_list = []

        # Özel durum kontrolü
        for ozel_ek, ayrilma_sekli in ozel_durumlar.items():
            if input_str.startswith(ozel_ek):
                for ayrilma in ayrilma_sekli:
                    for ad, ekler in ek_dosyalar.items():
                        if ayrilma in ekler and input_str.startswith(ayrilma):
                            en_uzun_ek = ayrilma
                            ek_adi = f"({ad})"
                            ozelBulundu = True
                            if ozelBulundu:
                                input_str = input_str[len(en_uzun_ek):].strip()
                                ek_adi_list.append(ek_adi)

        if not ozelBulundu:
            for ad, ekler in ek_dosyalar.items():
                for ek in ekler:
                    if input_str.endswith(ek) and len(ek) >= len(en_uzun_ek):
                        en_uzun_ek = ek
                        ek_adi = f"({ad})"
                        bulundu = True

            if bulundu:
                input_str = input_str[:-len(en_uzun_ek)].strip()
                for ad, ekler in ek_dosyalar.items():
                    if en_uzun_ek in ekler:
                        ek_adi_list.append(f"({ad})")
            else:
                ek_adi_list.append(f"({input_str})")

        if ek_adi_list:
            sonuclar.insert(0, (f"-{en_uzun_ek} ", ek_adi_list))
            en_uzun_ek = ""
            ek_adi_list = []

    print(sonuclar,"PUKAY BABA SONUCLAR")
    return sonuclar
    
def find_and_process_suffixes_v2(base_word, dataset_path):
    def find_suffixes(word, suffixes):
        found_suffixes = [suffix for suffix in suffixes if word.endswith(suffix)]
        for x in found_suffixes:
            print(x,"yakup ek")
        return found_suffixes

    def process_dataset(base_word, suffixes):
        matches = []
        suffix_categories = []
        matches2 = []
        suffix_categories2 = []
        new_base_word=""
        
        
        print(base_word,"process_dataya gelen base_word")
        print(suffixes,"bu da process_dataya gelen suffixes")
        with open(dataset_path, 'r', encoding='utf-8') as dataset_file:
            for line in dataset_file:
                parts = line.strip().split()

                if len(parts[0]):
                    current_word, word_type = parts[0], parts[1:]
                    
                    if not suffixes:
                        if base_word == current_word:
                            matches.append(current_word)
                            suffix_categories.append(f"({word_type})")
                    
                                
                        
                        
                    for suffix in suffixes:

                        
                        if base_word == current_word:

                            matches.append(current_word)
                            suffix_categories.append(f"({word_type})")
                            matches2.append(current_word)
                            suffix_categories2.append(f"({word_type})")
                            
                            
                            if any('CL_FIIL' in category for category in word_type):
                                return matches, ["CL_FIIL"],"",""
                                print("eyw")
                            else:
                                sonuclar = parcala_ve_kontrol_et(suffix)
                                print(sonuclar,"bunlar da sonuclar")
                                sonuclar2 = endswithKontrolu(suffix)
                                print(sonuclar2,"SONUCLAR 2")
                                for ek, dosya_adi in sonuclar:
                                    matches.append(ek)
                                    suffix_categories.append(f"({dosya_adi})")
                                for ek,dosya_adi in sonuclar2:
                                    print("BURAYA GIRIYON MU PEKI")
                                    matches2.append(ek)
                                    suffix_categories2.append(f"({dosya_adi})")
                        else:
                            if base_word.endswith('b'):
                                new_base_word = base_word[:-1] + 'p'
                            elif base_word.endswith('c'):
                                new_base_word = base_word[:-1] + 'ç'
                            elif base_word.endswith('d'):
                                new_base_word = base_word[:-1] + 't'
                            elif base_word.endswith('ğ'):
                                new_base_word = base_word[:-1] + 'k'
                            if new_base_word == current_word:
                                matches.append(current_word)
                                suffix_categories.append(f"({word_type})")

                                sonuclar = parcala_ve_kontrol_et(suffix)
                                print(sonuclar,"bunlar da sonuclar")
                                sonuclar2 = endswithKontrolu(suffix)
                                print(sonuclar2,"SONUCLAR 2")
                                for ek, dosya_adi in sonuclar:
                                    matches.append(ek)
                                    suffix_categories.append(f"({dosya_adi})")
                                for ek,dosya_adi in sonuclar2:
                                    print("BURAYA GIRIYON MU PEKI")
                                    matches2.append(ek)
                                    suffix_categories2.append(f"({dosya_adi})")
                                    
        print(matches2,"RETURN ETMEDEN ONCEKI MATCHES2")
        return matches, suffix_categories,matches2,suffix_categories2

    ihtimalVarmi = False
    fiilDondu=False
    
    unlu_dusmesi={
        "ağz":"ağız",
        "aln":"alın",
        "burn":"burun",
        "bağr":"bağır",
        "beyn":"beyin",
        "göğs":"göğüs",
        "karn":"karın",
        "omz":"omuz",
        "oğl":"oğul",
        "gönl":"gönül",
        "akl":"akıl",
        "fikr":"fikir",
        "cism":"cisim",
        "ayr":"ayır",
        "devr":"devir",
        "çevr":"çevir",
        "sıyr":"sıyır",
        "kıvr":"kıvır",
        "devr":"devir",
        "kayb":"kayıp",
        "haps":"hapis",
        "sabr":"sabır",
        "ufk":"ufuk",
        "benz":"beniz",
        "boyn":"boyun",
        "bağr":"bağır",
        "genz":"geniz",
        "gönl":"gönül",
        "oğl":"oğul",
        
    }
    
    
    
    with open('C:/endings.txt', 'r', encoding='utf-8') as endings_file:
        suffixes = [line.strip() for line in endings_file]

    eksizEslesme, suffix_categories,eksizEslesme2,suffix_categories2 = process_dataset(base_word, [])
        
    if any('CL_FIIL' in category for category in suffix_categories):
        #return 'Bu bir fiil oldugu icin burasi lokmandan gelecek'
        return deger(base_word)

    all_suffixes = find_suffixes(base_word, suffixes)

    if eksizEslesme:
        return ''.join(eksizEslesme), ''.join(suffix_categories)
    elif all_suffixes:
        result_suffixes = []
        
        for suffix in sorted(all_suffixes, key=len, reverse=True):
            print(suffix,"yakuk")
            remaining_word = base_word[:-len(suffix)]
            print(remaining_word,"bu da remaining word")
            if remaining_word.endswith(("iyor", "iyo", "üyor", "üyo")):
                if(not fiilDondu):
                    remaining_word = remaining_word.replace("iyor", "e").replace("iyo", "e").replace("üyor", "e").replace("üyo", "e", 1)
                    print(remaining_word,"yeni remaining word bu")
            if remaining_word.endswith(("ıyor", "ıyo", "uyor", "uyo")):
                if(not fiilDondu):
                    remaining_word = remaining_word.replace("ıyor", "a").replace("ıyo", "a").replace("uyor", "a").replace("uyo", "a", 1)
                    print(remaining_word,"yeni remaining word bu")
                    
            if remaining_word in unlu_dusmesi:
                remaining_word = unlu_dusmesi[remaining_word]
            
            matches, suffix_categories,matches2,suffix_categories2 = process_dataset(remaining_word, [suffix])
            print(matches,"bu matches")
            print(suffix_categories,"bu sofik kategori")
            print(matches2,"BU MATCHES2")

            if matches:

                if any(any(keyword in category for keyword in ('CL_FIIL', 'Apply', 'Become')) for category in suffix_categories):
                    #return 'Bu bir fiil oldugu icin burasi lokmandan gelecek'
                    if(ihtimalVarmi):
                            result_suffixes.extend('<br>')
                            result_suffixes.extend(f' <br> Eşleşen diğer bir seçenek: ')
                            result_suffixes.extend(deger(base_word))
                            result_suffixes.extend(' ')
                            tempBaseWord=base_word
                            fiilDondu=True
                            return ''.join(result_suffixes)
                        
                    else:
                        ihtimalVarmi = True
                        print(deger(base_word),"SFAJGJSDAGJASDLGASDKGJKSDLJL")
                        result_suffixes.extend(deger(base_word))
                        result_suffixes.extend(' ')
                        result_suffixes.extend('<br>')
                        fiilDondu=True
                        return ''.join(result_suffixes)
                    
                else:
                    if(ihtimalVarmi):
                        #if all("Trap_Eki" not in suffix_category for suffix_category in suffix_categories):
                            result_suffixes.extend('<br>')
                            result_suffixes.extend(f' <br> Eşleşen diğer bir seçenek: ')
                            result_suffixes.extend(matches)
                            result_suffixes.extend(suffix_categories)
                            result_suffixes.extend(' ')
                            if(matches != matches2 and suffix_categories != suffix_categories2):
                                result_suffixes.extend('<br>')
                                result_suffixes.extend('<br>')
                                result_suffixes.extend(matches2)
                                result_suffixes.extend(suffix_categories2)
                                result_suffixes.extend(' ')
                    else:
                        #if all("Trap_Eki" not in suffix_category for suffix_category in suffix_categories):
                        ihtimalVarmi=True
                        result_suffixes.extend(matches)
                        result_suffixes.extend(suffix_categories)
                        result_suffixes.extend(' ')
                        if(matches != matches2 and suffix_categories != suffix_categories2):
                            result_suffixes.extend('<br>')
                            result_suffixes.extend('<br>')
                            result_suffixes.extend(matches2)
                            result_suffixes.extend(suffix_categories2)
                            result_suffixes.extend(' ')
                        

            else:
                #kontrolVar=deger(base_word)
                #if(kontrolVar):
                    #result_suffixes.extend(deger(base_word))
               # else:
                    #return f"{base_word} kelimesi için eşleşme bulunamadı."
                print("sebze")

                        

        return ''.join(result_suffixes)

        
        
@app.route("/", methods=["GET", "POST"])
def index():
    results = []
    root_list_path = 'C:/dataset.txt'
    suffix_list_path = 'C:/endings.txt'
    with open(root_list_path, 'r', encoding='utf-8') as root_file:
        root_list = [line.strip().split()[0] for line in root_file]

    with open(suffix_list_path, 'r', encoding='utf-8') as suffix_file:
        suffix_list = [line.strip() for line in suffix_file]

    if request.method == "POST":
        if request.form.get("generate_random_sentence"):
            user_input = get_random_sentence('C:/turkceCumleler.txt')
        else:
            user_input = request.form.get("user_input", "")
    else:
        user_input = ""

    user_input = user_input.lower()
    user_input = user_input.replace("'", ' ').replace('"', '').replace(',',' ').replace(';',' ')
    normalizasyonAktif = request.form.get("normalizasyonAktif")

    sentences = sentence_splitter(user_input)

    for sentence in sentences:
        tokens = tokenizer(sentence)
        processed_tokens = []

        for token in tokens:
            if normalizasyonAktif == "True":
                corrected_word = correct_input(token, root_list, suffix_list)
                result = find_and_process_suffixes_v2(corrected_word, 'C:/dataset.txt')
                processed_tokens.append((corrected_word, result))
            elif normalizasyonAktif == "False":
                result = find_and_process_suffixes_v2(token, 'C:/dataset.txt')
                processed_tokens.append((token, result))

        results.append(processed_tokens)
            
    return render_template("index.html", results=results, user_input=user_input)


@app.route('/developers')
def developers():
    return render_template('developers.html')

if __name__ == "__main__":
    app.run(debug=True, use_reloader=False)
# Out:
# uy+ ('ar+ım', 'Verb+Aor+A1sg')
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [18/Jan/2024 19:42:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:42:12] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:42:12] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:42:16] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:42:16] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:42:16] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# sakla process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:42:26] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:42:26] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:42:26] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# gönderiyorum process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# iyorum yakup ek
# m yakup ek
# rum yakup ek
# um yakup ek
# iyorum yakuk
# gönder bu da remaining word
# gönder process_dataya gelen base_word
# ['iyorum'] bu da process_dataya gelen suffixes
# ['gönder'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# gönder+ ('iyor+um', 'Verb+Prog+A1sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:42:29] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:42:29] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:42:29] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# gönder process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:43:44] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:43:44] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:43:44] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# modül process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ül yakup ek
# modülleri process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# eri yakup ek
# i yakup ek
# leri yakup ek
# ri yakup ek
# leri yakuk
# modül bu da remaining word
# modül process_dataya gelen base_word
# ['leri'] bu da process_dataya gelen suffixes
# [('-leri ', ['(P3pl)'])] YKAUP BABA SONUCLAR
# [('-leri ', ['(P3pl)'])] bunlar da sonuclar
# [('-leri ', ['(P3pl)'])] PUKAY BABA SONUCLAR
# [('-leri ', ['(P3pl)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['modül', '-leri '] RETURN ETMEDEN ONCEKI MATCHES2
# ['modül', '-leri '] bu matches
# ["(['CL_ISIM'])", "(['(P3pl)'])"] bu sofik kategori
# ['modül', '-leri '] BU MATCHES2
# eri yakuk
# modüll bu da remaining word
# modüll process_dataya gelen base_word
# ['eri'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ri yakuk
# modülle bu da remaining word
# modülle process_dataya gelen base_word
# ['ri'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# i yakuk
# modüller bu da remaining word
# modüller process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# geliştirip process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ip yakup ek
# tirip yakup ek
# tirip yakup ek
# tirip yakuk
# geliş bu da remaining word
# geliş process_dataya gelen base_word
# ['tirip'] bu da process_dataya gelen suffixes
# ['geliş'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# geliş+ ('tir+ip', 'Verb+Caus+AfterDoing+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# ileri process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# eri yakup ek
# i yakup ek
# ileri yakup ek
# leri yakup ek
# ri yakup ek
# seviye process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# ye yakup ek
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# program process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# m yakup ek
# yapabiliriz process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# abiliriz yakup ek
# iliriz yakup ek
# iriz yakup ek
# iz yakup ek
# riz yakup ek
# abiliriz yakuk
# yap bu da remaining word
# yap process_dataya gelen base_word
# ['abiliriz'] bu da process_dataya gelen suffixes
# 127.0.0.1 - - [18/Jan/2024 19:44:20] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:44:20] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:44:20] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# ['yap'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# yap+ ('abil+ir+iz', 'Verb+Abil+Aor+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# kullandığımız process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dığımız yakup ek
# ımız yakup ek
# ız yakup ek
# landığımız yakup ek
# mız yakup ek
# ndığımız yakup ek
# landığımız yakuk
# kul bu da remaining word
# kul process_dataya gelen base_word
# ['landığımız'] bu da process_dataya gelen suffixes
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] YKAUP BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] bunlar da sonuclar
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] PUKAY BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] RETURN ETMEDEN ONCEKI MATCHES2
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] bu matches
# ["(['CL_ISIM'])", "(['(Acquire)'])", "(['(Trap_Eki)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(P1pl)'])"] bu sofik kategori
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] BU MATCHES2
# ndığımız yakuk
# kulla bu da remaining word
# kulla process_dataya gelen base_word
# ['ndığımız'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# dığımız yakuk
# kullan bu da remaining word
# kullan process_dataya gelen base_word
# ['dığımız'] bu da process_dataya gelen suffixes
# ['kullan'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# modülleri process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# eri yakup ek
# i yakup ek
# leri yakup ek
# ri yakup ek
# leri yakuk
# modül bu da remaining word
# modül process_dataya gelen base_word
# ['leri'] bu da process_dataya gelen suffixes
# [('-leri ', ['(P3pl)'])] YKAUP BABA SONUCLAR
# [('-leri ', ['(P3pl)'])] bunlar da sonuclar
# [('-leri ', ['(P3pl)'])] PUKAY BABA SONUCLAR
# [('-leri ', ['(P3pl)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['modül', '-leri '] RETURN ETMEDEN ONCEKI MATCHES2
# ['modül', '-leri '] bu matches
# ["(['CL_ISIM'])", "(['(P3pl)'])"] bu sofik kategori
# ['modül', '-leri '] BU MATCHES2
# eri yakuk
# modüll bu da remaining word
# modüll process_dataya gelen base_word
# ['eri'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ri yakuk
# modülle bu da remaining word
# modülle process_dataya gelen base_word
# ['ri'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# i yakuk
# modüller bu da remaining word
# modüller process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# geliştirip process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ip yakup ek
# tirip yakup ek
# tirip yakup ek
# tirip yakuk
# geliş bu da remaining word
# geliş process_dataya gelen base_word
# ['tirip'] bu da process_dataya gelen suffixes
# ['geliş'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# geliş+ ('tir+ip', 'Verb+Caus+AfterDoing+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# ileri process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# eri yakup ek
# i yakup ek
# ileri yakup ek
# leri yakup ek
# ri yakup ek
# seviyede process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# de yakup ek
# e yakup ek
# de yakuk
# seviye bu da remaining word
# seviye process_dataya gelen base_word
# ['de'] bu da process_dataya gelen suffixes
# [('-de ', ['(Loc)', '(Division)'])] YKAUP BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] bunlar da sonuclar
# [('-de ', ['(Loc)', '(Division)'])] PUKAY BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['seviye', '-de '] RETURN ETMEDEN ONCEKI MATCHES2
# ['seviye', '-de '] bu matches
# ["(['CL_ISIM'])", "(['(Loc)', '(Division)'])"] bu sofik kategori
# ['seviye', '-de '] BU MATCHES2
# e yakuk
# seviyed bu da remaining word
# seviyed process_dataya gelen base_word
# ['e'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# sonuç process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# üreten process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# en yakup ek
# n yakup ek
# ten yakup ek
# ten yakuk
# üre bu da remaining word
# üre process_dataya gelen base_word
# ['ten'] bu da process_dataya gelen suffixes
# ['üre'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# üre+ ('t+en', 'Verb+Caus+PresPart+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:44:52] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:44:52] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# program process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# m yakup ek
# yapabiliriz process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# abiliriz yakup ek
# iliriz yakup ek
# iriz yakup ek
# iz yakup ek
# riz yakup ek
# abiliriz yakuk
# yap bu da remaining word
# yap process_dataya gelen base_word
# ['abiliriz'] bu da process_dataya gelen suffixes
# ['yap'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# yap+ ('abil+ir+iz', 'Verb+Abil+Aor+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:44:52] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# kullandık process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# andık yakup ek
# dık yakup ek
# landık yakup ek
# ndık yakup ek
# landık yakuk
# kul bu da remaining word
# kul process_dataya gelen base_word
# ['landık'] bu da process_dataya gelen suffixes
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-k ', ['(A1pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-k ', ['(A1pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-k ', ['(A1pl)', '(Trap_Eki)'])] PUKAY BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-k ', ['(A1pl)', '(Trap_Eki)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['kul', '-lan ', '-d ', '-ı ', '-k '] RETURN ETMEDEN ONCEKI MATCHES2
# ['kul', '-lan ', '-d ', '-ı ', '-k '] bu matches
# ["(['CL_ISIM'])", "(['(Acquire)'])", "(['(Trap_Eki)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])", "(['(A1pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['kul', '-lan ', '-d ', '-ı ', '-k '] BU MATCHES2
# andık yakuk
# kull bu da remaining word
# kull process_dataya gelen base_word
# ['andık'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ndık yakuk
# kulla bu da remaining word
# kulla process_dataya gelen base_word
# ['ndık'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# dık yakuk
# kullan bu da remaining word
# kullan process_dataya gelen base_word
# ['dık'] bu da process_dataya gelen suffixes
# ['kullan'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:45:41] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:45:41] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:45:41] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:45:56] "POST / HTTP/1.1" 200 -
# kullandığımız process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dığımız yakup ek
# ımız yakup ek
# ız yakup ek
# landığımız yakup ek
# mız yakup ek
# ndığımız yakup ek
# landığımız yakuk
# kul bu da remaining word
# kul process_dataya gelen base_word
# ['landığımız'] bu da process_dataya gelen suffixes
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] YKAUP BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] bunlar da sonuclar
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] PUKAY BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] RETURN ETMEDEN ONCEKI MATCHES2
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] bu matches
# ["(['CL_ISIM'])", "(['(Acquire)'])", "(['(Trap_Eki)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(P1pl)'])"] bu sofik kategori
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] BU MATCHES2
# ndığımız yakuk
# kulla bu da remaining word
# kulla process_dataya gelen base_word
# ['ndığımız'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# dığımız yakuk
# kullan bu da remaining word
# kullan process_dataya gelen base_word
# ['dığımız'] bu da process_dataya gelen suffixes
# ['kullan'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:45:56] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:45:56] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:46:44] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:46:44] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:46:44] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# attık process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# tık yakup ek
# tık yakup ek
# tık yakuk
# at bu da remaining word
# at process_dataya gelen base_word
# ['tık'] bu da process_dataya gelen suffixes
# ['at'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# at+ ('tı+k', 'Verb+Past+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:46:48] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:46:48] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:46:48] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# attığımız process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ımız yakup ek
# ız yakup ek
# mız yakup ek
# tığımız yakup ek
# tığımız yakup ek
# tığımız yakuk
# at bu da remaining word
# at process_dataya gelen base_word
# ['tığımız'] bu da process_dataya gelen suffixes
# ['at'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# at+ ('tığ+ım+ız', 'Verb+CausPart+A1sg+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:47:05] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:47:05] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:47:05] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# kullandığımız process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dığımız yakup ek
# ımız yakup ek
# ız yakup ek
# landığımız yakup ek
# mız yakup ek
# ndığımız yakup ek
# landığımız yakuk
# kul bu da remaining word
# kul process_dataya gelen base_word
# ['landığımız'] bu da process_dataya gelen suffixes
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] YKAUP BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] bunlar da sonuclar
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] PUKAY BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] RETURN ETMEDEN ONCEKI MATCHES2
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] bu matches
# ["(['CL_ISIM'])", "(['(Acquire)'])", "(['(Trap_Eki)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(P1pl)'])"] bu sofik kategori
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] BU MATCHES2
# ndığımız yakuk
# kulla bu da remaining word
# kulla process_dataya gelen base_word
# ['ndığımız'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# dığımız yakuk
# kullan bu da remaining word
# kullan process_dataya gelen base_word
# ['dığımız'] bu da process_dataya gelen suffixes
# ['kullan'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:47:11] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:47:11] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:47:11] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# aldığımız process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dığımız yakup ek
# ımız yakup ek
# ız yakup ek
# mız yakup ek
# dığımız yakuk
# al bu da remaining word
# al process_dataya gelen base_word
# ['dığımız'] bu da process_dataya gelen suffixes
# ['al'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# al+ ('dığ+ım+ız', 'Verb+PastPart+A1sg+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:47:18] "POST / HTTP/1.1" 200 -
# kullandığımız process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dığımız yakup ek
# ımız yakup ek
# ız yakup ek
# landığımız yakup ek
# mız yakup ek
# ndığımız yakup ek
# landığımız yakuk
# kul bu da remaining word
# kul process_dataya gelen base_word
# ['landığımız'] bu da process_dataya gelen suffixes
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] YKAUP BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] bunlar da sonuclar
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] PUKAY BABA SONUCLAR
# [('-lan ', ['(Acquire)']), ('-d ', ['(Trap_Eki)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ğ ', ['(Trap_Eki)']), ('-ımız ', ['(P1pl)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] RETURN ETMEDEN ONCEKI MATCHES2
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] bu matches
# ["(['CL_ISIM'])", "(['(Acquire)'])", "(['(Trap_Eki)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(P1pl)'])"] bu sofik kategori
# ['kul', '-lan ', '-d ', '-ı ', '-ğ ', '-ımız '] BU MATCHES2
# ndığımız yakuk
# kulla bu da remaining word
# kulla process_dataya gelen base_word
# ['ndığımız'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# dığımız yakuk
# kullan bu da remaining word
# kullan process_dataya gelen base_word
# ['dığımız'] bu da process_dataya gelen suffixes
# ['kullan'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:47:18] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:47:18] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:48:08] "GET /developers HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:48:08] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:48:08] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:48:08] "GET /static/cvs/yakupcv.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:48:08] "GET /static/cvs/lokmancv.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:48:11] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:48:11] "GET /static/js/bootstrap.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:48:11] "GET /static/css/bootstrap.css.map HTTP/1.1" 200 -
# mesajlaşıyorum process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ıyorum yakup ek
# laşıyorum yakup ek
# m yakup ek
# rum yakup ek
# um yakup ek
# laşıyorum yakuk
# mesaj bu da remaining word
# mesaj process_dataya gelen base_word
# ['laşıyorum'] bu da process_dataya gelen suffixes
# [('-laş ', ['(Become)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-y ', ['(Trap_Eki)']), ('-o ', ['(Trap_Eki)']), ('-r ', ['(Trap_Eki)']), ('-um ', ['(Gen)', '(P1sg)', '(A1sg)'])] YKAUP BABA SONUCLAR
# [('-laş ', ['(Become)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-y ', ['(Trap_Eki)']), ('-o ', ['(Trap_Eki)']), ('-r ', ['(Trap_Eki)']), ('-um ', ['(Gen)', '(P1sg)', '(A1sg)'])] bunlar da sonuclar
# [('-laş ', ['(Become)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-y ', ['(Trap_Eki)']), ('-o ', ['(Trap_Eki)']), ('-r ', ['(Trap_Eki)']), ('-um ', ['(Gen)', '(P1sg)', '(A1sg)'])] PUKAY BABA SONUCLAR
# [('-laş ', ['(Become)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-y ', ['(Trap_Eki)']), ('-o ', ['(Trap_Eki)']), ('-r ', ['(Trap_Eki)']), ('-um ', ['(Gen)', '(P1sg)', '(A1sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['mesaj', '-laş ', '-ı ', '-y ', '-o ', '-r ', '-um '] RETURN ETMEDEN ONCEKI MATCHES2
# ['mesaj', '-laş ', '-ı ', '-y ', '-o ', '-r ', '-um '] bu matches
# ["(['CL_ISIM'])", "(['(Become)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(Trap_Eki)'])", "(['(Gen)', '(P1sg)', '(A1sg)'])"] bu sofik kategori
# ['mesaj', '-laş ', '-ı ', '-y ', '-o ', '-r ', '-um '] BU MATCHES2
# mesaj+('laş+ıyor+um', 'Verb+Become+Prog+A1sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:48:35] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:48:35] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:48:35] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# doğal process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dil process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# işleme process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# eme yakup ek
# me yakup ek
# projesi process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# esi yakup ek
# i yakup ek
# si yakup ek
# esi yakuk
# proj bu da remaining word
# proj process_dataya gelen base_word
# ['esi'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# si yakuk
# proje bu da remaining word
# proje process_dataya gelen base_word
# ['si'] bu da process_dataya gelen suffixes
# [('-si ', ['(P3sg)'])] YKAUP BABA SONUCLAR
# [('-si ', ['(P3sg)'])] bunlar da sonuclar
# [('-si ', ['(P3sg)'])] PUKAY BABA SONUCLAR
# [('-si ', ['(P3sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['proje', '-si '] RETURN ETMEDEN ONCEKI MATCHES2
# ['proje', '-si '] bu matches
# ["(['CL_ISIM'])", "(['(P3sg)'])"] bu sofik kategori
# ['proje', '-si '] BU MATCHES2
# i yakuk
# projes bu da remaining word
# projes process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# metinlerin process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# erin yakup ek
# in yakup ek
# lerin yakup ek
# n yakup ek
# rin yakup ek
# lerin yakuk
# metin bu da remaining word
# metin process_dataya gelen base_word
# ['lerin'] bu da process_dataya gelen suffixes
# [('-leri ', ['(P3pl)']), ('-n ', ['(P2sg)', '(A2sg)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-leri ', ['(P3pl)']), ('-n ', ['(P2sg)', '(A2sg)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ler ', ['(Pl)', '(A3pl)']), ('-in ', ['(Gen)', '(P2sg)', '(A2sg)'])] PUKAY BABA SONUCLAR
# [('-ler ', ['(Pl)', '(A3pl)']), ('-in ', ['(Gen)', '(P2sg)', '(A2sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['metin', '-ler ', '-in '] RETURN ETMEDEN ONCEKI MATCHES2
# ['metin', '-leri ', '-n '] bu matches
# ["(['CL_ISIM', 'IS_OA', 'IS_UD', 'IS_UDD'])", "(['(P3pl)'])", "(['(P2sg)', '(A2sg)', '(Trap_Eki)'])"] bu sofik kategori
# ['metin', '-ler ', '-in '] BU MATCHES2
# erin yakuk
# metinl bu da remaining word
# metinl process_dataya gelen base_word
# ['erin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# rin yakuk
# metinle bu da remaining word
# metinle process_dataya gelen base_word
# ['rin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# in yakuk
# metinler bu da remaining word
# metinler process_dataya gelen base_word
# ['in'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# n yakuk
# metinleri bu da remaining word
# metinleri process_dataya gelen base_word
# ['n'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamını process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# ını yakup ek
# nı yakup ek
# ını yakuk
# anlam bu da remaining word
# anlam process_dataya gelen base_word
# ['ını'] bu da process_dataya gelen suffixes
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['anlam', '-ı ', '-nı '] RETURN ETMEDEN ONCEKI MATCHES2
# ['anlam', '-ın ', '-ı '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['anlam', '-ı ', '-nı '] BU MATCHES2
# nı yakuk
# anlamı bu da remaining word
# anlamı process_dataya gelen base_word
# ['nı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ı yakuk
# anlamın bu da remaining word
# anlamın process_dataya gelen base_word
# ['ı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# doğru process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ru yakup ek
# u yakup ek
# ve process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# verimli process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# li yakup ek
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# şekilde process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# de yakup ek
# e yakup ek
# de yakuk
# şekil bu da remaining word
# şekil process_dataya gelen base_word
# ['de'] bu da process_dataya gelen suffixes
# [('-de ', ['(Loc)', '(Division)'])] YKAUP BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] bunlar da sonuclar
# [('-de ', ['(Loc)', '(Division)'])] PUKAY BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['şekil', '-de '] RETURN ETMEDEN ONCEKI MATCHES2
# ['şekil', '-de '] bu matches
# ["(['CL_ISIM', 'IS_UD'])", "(['(Loc)', '(Division)'])"] bu sofik kategori
# ['şekil', '-de '] BU MATCHES2
# e yakuk
# şekild bu da remaining word
# şekild process_dataya gelen base_word
# ['e'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamamızı process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# mamızı yakup ek
# mızı yakup ek
# mamızı yakuk
# anla bu da remaining word
# anla process_dataya gelen base_word
# ['mamızı'] bu da process_dataya gelen suffixes
# ['anla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# 127.0.0.1 - - [18/Jan/2024 19:52:05] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:52:05] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:52:05] "
# anla+ ('ma+m+ız', 'Verb+Neg+A1sg+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# sağlayacaktır process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# acaktır yakup ek
# ır yakup ek
# r yakup ek
# tır yakup ek
# tır yakup ek
# yacaktır yakup ek
# yacaktır yakuk
# sağla bu da remaining word
# sağla process_dataya gelen base_word
# ['yacaktır'] bu da process_dataya gelen suffixes
# ['sağla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# sağla+ ('yacak+tır', 'Verb+Fut+Caus+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:52:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:52:37] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:52:37] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# doğal process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dil process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# il yakup ek
# işleme process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# eme yakup ek
# me yakup ek
# projesi process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# esi yakup ek
# i yakup ek
# si yakup ek
# esi yakuk
# proj bu da remaining word
# proj process_dataya gelen base_word
# ['esi'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# si yakuk
# proje bu da remaining word
# proje process_dataya gelen base_word
# ['si'] bu da process_dataya gelen suffixes
# [('-si ', ['(P3sg)'])] YKAUP BABA SONUCLAR
# [('-si ', ['(P3sg)'])] bunlar da sonuclar
# [('-si ', ['(P3sg)'])] PUKAY BABA SONUCLAR
# [('-si ', ['(P3sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['proje', '-si '] RETURN ETMEDEN ONCEKI MATCHES2
# ['proje', '-si '] bu matches
# ["(['CL_ISIM'])", "(['(P3sg)'])"] bu sofik kategori
# ['proje', '-si '] BU MATCHES2
# i yakuk
# projes bu da remaining word
# projes process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# metinlerin process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# erin yakup ek
# in yakup ek
# lerin yakup ek
# n yakup ek
# rin yakup ek
# lerin yakuk
# metin bu da remaining word
# metin process_dataya gelen base_word
# ['lerin'] bu da process_dataya gelen suffixes
# [('-leri ', ['(P3pl)']), ('-n ', ['(P2sg)', '(A2sg)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-leri ', ['(P3pl)']), ('-n ', ['(P2sg)', '(A2sg)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ler ', ['(Pl)', '(A3pl)']), ('-in ', ['(Gen)', '(P2sg)', '(A2sg)'])] PUKAY BABA SONUCLAR
# [('-ler ', ['(Pl)', '(A3pl)']), ('-in ', ['(Gen)', '(P2sg)', '(A2sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['metin', '-ler ', '-in '] RETURN ETMEDEN ONCEKI MATCHES2
# ['metin', '-leri ', '-n '] bu matches
# ["(['CL_ISIM', 'IS_OA', 'IS_UD', 'IS_UDD'])", "(['(P3pl)'])", "(['(P2sg)', '(A2sg)', '(Trap_Eki)'])"] bu sofik kategori
# ['metin', '-ler ', '-in '] BU MATCHES2
# erin yakuk
# metinl bu da remaining word
# metinl process_dataya gelen base_word
# ['erin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# rin yakuk
# metinle bu da remaining word
# metinle process_dataya gelen base_word
# ['rin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# in yakuk
# metinler bu da remaining word
# metinler process_dataya gelen base_word
# ['in'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# n yakuk
# metinleri bu da remaining word
# metinleri process_dataya gelen base_word
# ['n'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamını process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# ını yakup ek
# nı yakup ek
# ını yakuk
# anlam bu da remaining word
# anlam process_dataya gelen base_word
# ['ını'] bu da process_dataya gelen suffixes
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['anlam', '-ı ', '-nı '] RETURN ETMEDEN ONCEKI MATCHES2
# ['anlam', '-ın ', '-ı '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['anlam', '-ı ', '-nı '] BU MATCHES2
# nı yakuk
# anlamı bu da remaining word
# anlamı process_dataya gelen base_word
# ['nı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ı yakuk
# anlamın bu da remaining word
# anlamın process_dataya gelen base_word
# ['ı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# doğru process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ru yakup ek
# u yakup ek
# ve process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# verimli process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# li yakup ek
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# şekilde process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# de yakup ek
# e yakup ek
# de yakuk
# şekil bu da remaining word
# şekil process_dataya gelen base_word
# ['de'] bu da process_dataya gelen suffixes
# [('-de ', ['(Loc)', '(Division)'])] YKAUP BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] bunlar da sonuclar
# [('-de ', ['(Loc)', '(Division)'])] PUKAY BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['şekil', '-de '] RETURN ETMEDEN ONCEKI MATCHES2
# ['şekil', '-de '] bu matches
# ["(['CL_ISIM', 'IS_UD'])", "(['(Loc)', '(Division)'])"] bu sofik kategori
# ['şekil', '-de '] BU MATCHES2
# e yakuk
# şekild bu da remaining word
# şekild process_dataya gelen base_word
# ['e'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamamızı process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# mamızı yakup ek
# mızı yakup ek
# mamızı yakuk
# anla bu da remaining word
# anla process_dataya gelen base_word
# ['mamızı'] bu da process_dataya gelen suffixes
# ['anla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# anla+ ('ma+m+ız', 'Verb+Neg+A1sg+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 19:52:41] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:52:41] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:52:41] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# sağlayacaktır process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# acaktır yakup ek
# ır yakup ek
# r yakup ek
# tır yakup ek
# tır yakup ek
# yacaktır yakup ek
# yacaktır yakuk
# sağla bu da remaining word
# sağla process_dataya gelen base_word
# ['yacaktır'] bu da process_dataya gelen suffixes
# ['sağla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# sağla+ ('yacak+tır', 'Verb+Fut+Caus+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# doğal process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dil process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# il yakup ek
# işleme process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# eme yakup ek
# me yakup ek
# projesi process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# esi yakup ek
# i yakup ek
# si yakup ek
# esi yakuk
# proj bu da remaining word
# proj process_dataya gelen base_word
# ['esi'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# si yakuk
# proje bu da remaining word
# proje process_dataya gelen base_word
# ['si'] bu da process_dataya gelen suffixes
# [('-si ', ['(P3sg)'])] YKAUP BABA SONUCLAR
# [('-si ', ['(P3sg)'])] bunlar da sonuclar
# [('-si ', ['(P3sg)'])] PUKAY BABA SONUCLAR
# [('-si ', ['(P3sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['proje', '-si '] RETURN ETMEDEN ONCEKI MATCHES2
# ['proje', '-si '] bu matches
# ["(['CL_ISIM'])", "(['(P3sg)'])"] bu sofik kategori
# ['proje', '-si '] BU MATCHES2
# i yakuk
# projes bu da remaining word
# projes process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# metinlerin process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# erin yakup ek
# in yakup ek
# lerin yakup ek
# n yakup ek
# rin yakup ek
# lerin yakuk
# metin bu da remaining word
# metin process_dataya gelen base_word
# ['lerin'] bu da process_dataya gelen suffixes
# [('-leri ', ['(P3pl)']), ('-n ', ['(P2sg)', '(A2sg)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-leri ', ['(P3pl)']), ('-n ', ['(P2sg)', '(A2sg)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ler ', ['(Pl)', '(A3pl)']), ('-in ', ['(Gen)', '(P2sg)', '(A2sg)'])] PUKAY BABA SONUCLAR
# [('-ler ', ['(Pl)', '(A3pl)']), ('-in ', ['(Gen)', '(P2sg)', '(A2sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['metin', '-ler ', '-in '] RETURN ETMEDEN ONCEKI MATCHES2
# ['metin', '-leri ', '-n '] bu matches
# ["(['CL_ISIM', 'IS_OA', 'IS_UD', 'IS_UDD'])", "(['(P3pl)'])", "(['(P2sg)', '(A2sg)', '(Trap_Eki)'])"] bu sofik kategori
# ['metin', '-ler ', '-in '] BU MATCHES2
# erin yakuk
# metinl bu da remaining word
# metinl process_dataya gelen base_word
# ['erin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# rin yakuk
# metinle bu da remaining word
# metinle process_dataya gelen base_word
# ['rin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# in yakuk
# metinler bu da remaining word
# metinler process_dataya gelen base_word
# ['in'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# n yakuk
# metinleri bu da remaining word
# metinleri process_dataya gelen base_word
# ['n'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamını process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# ını yakup ek
# nı yakup ek
# ını yakuk
# anlam bu da remaining word
# anlam process_dataya gelen base_word
# ['ını'] bu da process_dataya gelen suffixes
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['anlam', '-ı ', '-nı '] RETURN ETMEDEN ONCEKI MATCHES2
# ['anlam', '-ın ', '-ı '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['anlam', '-ı ', '-nı '] BU MATCHES2
# nı yakuk
# anlamı bu da remaining word
# anlamı process_dataya gelen base_word
# ['nı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ı yakuk
# anlamın bu da remaining word
# anlamın process_dataya gelen base_word
# ['ı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# doğru process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ru yakup ek
# u yakup ek
# ve process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# verimli process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# li yakup ek
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# şekilde process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# de yakup ek
# e yakup ek
# de yakuk
# şekil bu da remaining word
# şekil process_dataya gelen base_word
# ['de'] bu da process_dataya gelen suffixes
# [('-de ', ['(Loc)', '(Division)'])] YKAUP BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] bunlar da sonuclar
# [('-de ', ['(Loc)', '(Division)'])] PUKAY BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['şekil', '-de '] RETURN ETMEDEN ONCEKI MATCHES2
# ['şekil', '-de '] bu matches
# ["(['CL_ISIM', 'IS_UD'])", "(['(Loc)', '(Division)'])"] bu sofik kategori
# ['şekil', '-de '] BU MATCHES2
# e yakuk
# şekild bu da remaining word
# şekild process_dataya gelen base_word
# ['e'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# işlememizi process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# memizi yakup ek
# mizi yakup ek
# memizi yakuk
# işle bu da remaining word
# işle process_dataya gelen base_word
# ['memizi'] bu da process_dataya gelen suffixes
# ['işle'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# işle+ ('me+m+iz', 'Verb+Neg+A1sg+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
# sağlayacaktır process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# acaktır yakup ek
# ır yakup ek
# r yakup ek
# tır yakup ek
# tır yakup ek
# yacaktır yakup ek
# yacaktır yakuk
# sağla bu da remaining word
# sağla process_dataya gelen base_word
# ['yacaktır'] bu da process_dataya gelen suffixes
# 127.0.0.1 - - [18/Jan/2024 19:53:18] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:53:18] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:53:18] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# ['sağla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# sağla+ ('yacak+tır', 'Verb+Fut+Caus+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# doğal process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dil process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# il yakup ek
# işleme process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# eme yakup ek
# me yakup ek
# projesi process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# esi yakup ek
# i yakup ek
# si yakup ek
# esi yakuk
# proj bu da remaining word
# ...
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['metin', '-ler ', '-in '] RETURN ETMEDEN ONCEKI MATCHES2
# ['metin', '-leri ', '-n '] bu matches
# ["(['CL_ISIM', 'IS_OA', 'IS_UD', 'IS_UDD'])", "(['(P3pl)'])", "(['(P2sg)', '(A2sg)', '(Trap_Eki)'])"] bu sofik kategori
# ['metin', '-ler ', '-in '] BU MATCHES2
# erin yakuk
# metinl bu da remaining word
# metinl process_dataya gelen base_word
# ['erin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# rin yakuk
# metinle bu da remaining word
# metinle process_dataya gelen base_word
# ['rin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# in yakuk
# metinler bu da remaining word
# metinler process_dataya gelen base_word
# ['in'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# n yakuk
# metinleri bu da remaining word
# metinleri process_dataya gelen base_word
# ['n'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamını process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# ını yakup ek
# nı yakup ek
# ını yakuk
# anlam bu da remaining word
# anlam process_dataya gelen base_word
# ['ını'] bu da process_dataya gelen suffixes
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['anlam', '-ı ', '-nı '] RETURN ETMEDEN ONCEKI MATCHES2
# ['anlam', '-ın ', '-ı '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['anlam', '-ı ', '-nı '] BU MATCHES2
# nı yakuk
# anlamı bu da remaining word
# anlamı process_dataya gelen base_word
# ['nı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ı yakuk
# anlamın bu da remaining word
# anlamın process_dataya gelen base_word
# ['ı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# doğru process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ru yakup ek
# u yakup ek
# ve process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# verimli process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# li yakup ek
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# şekilde process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# de yakup ek
# e yakup ek
# de yakuk
# şekil bu da remaining word
# şekil process_dataya gelen base_word
# ['de'] bu da process_dataya gelen suffixes
# [('-de ', ['(Loc)', '(Division)'])] YKAUP BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] bunlar da sonuclar
# [('-de ', ['(Loc)', '(Division)'])] PUKAY BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['şekil', '-de '] RETURN ETMEDEN ONCEKI MATCHES2
# ['şekil', '-de '] bu matches
# ["(['CL_ISIM', 'IS_UD'])", "(['(Loc)', '(Division)'])"] bu sofik kategori
# ['şekil', '-de '] BU MATCHES2
# e yakuk
# şekild bu da remaining word
# şekild process_dataya gelen base_word
# ['e'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# analizini process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# ini yakup ek
# ni yakup ek
# ini yakuk
# analiz bu da remaining word
# analiz process_dataya gelen base_word
# ['ini'] bu da process_dataya gelen suffixes
# [('-in ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-in ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ni ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ni ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['analiz', '-i ', '-ni '] RETURN ETMEDEN ONCEKI MATCHES2
# ['analiz', '-in ', '-i '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['analiz', '-i ', '-ni '] BU MATCHES2
# ni yakuk
# analizi bu da remaining word
# analizi process_dataya gelen base_word
# ['ni'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# i yakuk
# analizin bu da remaining word
# analizin process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# 127.0.0.1 - - [18/Jan/2024 19:55:45] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:55:45] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:55:45] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# sağlayabilecektir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# abilecektir yakup ek
# ecektir yakup ek
# ilecektir yakup ek
# ir yakup ek
# r yakup ek
# tir yakup ek
# tir yakup ek
# yabilecektir yakup ek
# yabilecektir yakuk
# sağla bu da remaining word
# sağla process_dataya gelen base_word
# ['yabilecektir'] bu da process_dataya gelen suffixes
# ['sağla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# sağla+ ('yabil+ecek+tir', 'Verb+Abil+Fut+Caus+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# doğal process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# dil process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# il yakup ek
# işleme process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# eme yakup ek
# me yakup ek
# projesi process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# esi yakup ek
# i yakup ek
# si yakup ek
# esi yakuk
# proj bu da remaining word
# proj process_dataya gelen base_word
# ['esi'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# si yakuk
# proje bu da remaining word
# proje process_dataya gelen base_word
# ['si'] bu da process_dataya gelen suffixes
# [('-si ', ['(P3sg)'])] YKAUP BABA SONUCLAR
# [('-si ', ['(P3sg)'])] bunlar da sonuclar
# [('-si ', ['(P3sg)'])] PUKAY BABA SONUCLAR
# [('-si ', ['(P3sg)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['proje', '-si '] RETURN ETMEDEN ONCEKI MATCHES2
# ['proje', '-si '] bu matches
# ["(['CL_ISIM'])", "(['(P3sg)'])"] bu sofik kategori
# ['proje', '-si '] BU MATCHES2
# i yakuk
# projes bu da remaining word
# projes process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# türkçe process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# çe yakup ek
# e yakup ek
# metinlerinin process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# erinin yakup ek
# in yakup ek
# inin yakup ek
# lerinin yakup ek
# n yakup ek
# nin yakup ek
# rinin yakup ek
# lerinin yakuk
# metin bu da remaining word
# metin process_dataya gelen base_word
# ['lerinin'] bu da process_dataya gelen suffixes
# [('-leri ', ['(P3pl)']), ('-nin ', ['(Gen)'])] YKAUP BABA SONUCLAR
# [('-leri ', ['(P3pl)']), ('-nin ', ['(Gen)'])] bunlar da sonuclar
# [('-leri ', ['(P3pl)']), ('-nin ', ['(Gen)'])] PUKAY BABA SONUCLAR
# [('-leri ', ['(P3pl)']), ('-nin ', ['(Gen)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['metin', '-leri ', '-nin '] RETURN ETMEDEN ONCEKI MATCHES2
# ['metin', '-leri ', '-nin '] bu matches
# ["(['CL_ISIM', 'IS_OA', 'IS_UD', 'IS_UDD'])", "(['(P3pl)'])", "(['(Gen)'])"] bu sofik kategori
# ['metin', '-leri ', '-nin '] BU MATCHES2
# erinin yakuk
# metinl bu da remaining word
# metinl process_dataya gelen base_word
# ['erinin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# rinin yakuk
# metinle bu da remaining word
# metinle process_dataya gelen base_word
# ['rinin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# inin yakuk
# metinler bu da remaining word
# metinler process_dataya gelen base_word
# ['inin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# nin yakuk
# metinleri bu da remaining word
# metinleri process_dataya gelen base_word
# ['nin'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# in yakuk
# metinlerin bu da remaining word
# metinlerin process_dataya gelen base_word
# ['in'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# n yakuk
# metinlerini bu da remaining word
# metinlerini process_dataya gelen base_word
# ['n'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# anlamını process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ı yakup ek
# ını yakup ek
# nı yakup ek
# ını yakuk
# anlam bu da remaining word
# anlam process_dataya gelen base_word
# ['ını'] bu da process_dataya gelen suffixes
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-ın ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-ı ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-nı ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['anlam', '-ı ', '-nı '] RETURN ETMEDEN ONCEKI MATCHES2
# ['anlam', '-ın ', '-ı '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['anlam', '-ı ', '-nı '] BU MATCHES2
# nı yakuk
# anlamı bu da remaining word
# anlamı process_dataya gelen base_word
# ['nı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# ı yakuk
# anlamın bu da remaining word
# anlamın process_dataya gelen base_word
# ['ı'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# daha process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# a yakup ek
# doğru process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ru yakup ek
# u yakup ek
# ve process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# e yakup ek
# verimli process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# li yakup ek
# bir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ir yakup ek
# r yakup ek
# şekilde process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# de yakup ek
# e yakup ek
# de yakuk
# şekil bu da remaining word
# şekil process_dataya gelen base_word
# ['de'] bu da process_dataya gelen suffixes
# [('-de ', ['(Loc)', '(Division)'])] YKAUP BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] bunlar da sonuclar
# [('-de ', ['(Loc)', '(Division)'])] PUKAY BABA SONUCLAR
# [('-de ', ['(Loc)', '(Division)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# ['şekil', '-de '] RETURN ETMEDEN ONCEKI MATCHES2
# ['şekil', '-de '] bu matches
# ["(['CL_ISIM', 'IS_UD'])", "(['(Loc)', '(Division)'])"] bu sofik kategori
# ['şekil', '-de '] BU MATCHES2
# e yakuk
# şekild bu da remaining word
# şekild process_dataya gelen base_word
# ['e'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# analizini process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# i yakup ek
# ini yakup ek
# ni yakup ek
# ini yakuk
# analiz bu da remaining word
# analiz process_dataya gelen base_word
# ['ini'] bu da process_dataya gelen suffixes
# [('-in ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] YKAUP BABA SONUCLAR
# [('-in ', ['(Gen)', '(P2sg)', '(A2sg)']), ('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])] bunlar da sonuclar
# [('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ni ', ['(Acc)'])] PUKAY BABA SONUCLAR
# [('-i ', ['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)']), ('-ni ', ['(Acc)'])] SONUCLAR 2
# BURAYA GIRIYON MU PEKI
# BURAYA GIRIYON MU PEKI
# ['analiz', '-i ', '-ni '] RETURN ETMEDEN ONCEKI MATCHES2
# ['analiz', '-in ', '-i '] bu matches
# ["(['CL_ISIM'])", "(['(Gen)', '(P2sg)', '(A2sg)'])", "(['(Acc)', '(P3sg)', '(P3pl)', '(Trap_Eki)'])"] bu sofik kategori
# ['analiz', '-i ', '-ni '] BU MATCHES2
# ni yakuk
# analizi bu da remaining word
# analizi process_dataya gelen base_word
# ['ni'] bu da process_dataya gelen suffixes
# 127.0.0.1 - - [18/Jan/2024 19:56:46] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 19:56:46] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 19:56:46] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# i yakuk
# analizin bu da remaining word
# analizin process_dataya gelen base_word
# ['i'] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# [] bu matches
# [] bu sofik kategori
# [] BU MATCHES2
# sebze
# sağlayabilecektir process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# abilecektir yakup ek
# ecektir yakup ek
# ilecektir yakup ek
# ir yakup ek
# r yakup ek
# tir yakup ek
# tir yakup ek
# yabilecektir yakup ek
# yabilecektir yakuk
# sağla bu da remaining word
# sağla process_dataya gelen base_word
# ['yabilecektir'] bu da process_dataya gelen suffixes
# ['sağla'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# sağla+ ('yabil+ecek+tir', 'Verb+Abil+Fut+Caus+A3sg') SFAJGJSDAGJASDLGASDKGJKSDLJL
# 127.0.0.1 - - [18/Jan/2024 20:26:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 20:26:25] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 20:26:25] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 20:26:27] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2024 20:26:27] "GET /static/css/bootstrap.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Jan/2024 20:26:28] "GET /static/js/bootstrap.js HTTP/1.1" 304 -
# yapıyoruz process_dataya gelen base_word
# [] bu da process_dataya gelen suffixes
# [] RETURN ETMEDEN ONCEKI MATCHES2
# ıyoruz yakup ek
# ruz yakup ek
# uz yakup ek
# ıyoruz yakuk
# yap bu da remaining word
# yap process_dataya gelen base_word
# ['ıyoruz'] bu da process_dataya gelen suffixes
# ['yap'] bu matches
# ['CL_FIIL'] bu sofik kategori
#  BU MATCHES2
# yap+ ('ıyor+uz', 'Verb+Prog+A1pl') SFAJGJSDAGJASDLGASDKGJKSDLJL
